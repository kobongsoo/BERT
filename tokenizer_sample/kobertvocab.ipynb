# %%
# Kobert sentencepiece vocab 을 wordpiece vocab으로 변환
# myutils 패키지 import
import sys
sys.path.append("..")
from myutils import SPVocabToWPVocab, AddWPVocabSpecialToken

# %%
outfile_fpath = "my_data1/kobert_vocab_02014.txt" # 출력(변환) 파일
#vocab_file="Tokenizer/kobert/kobert_news_wiki_ko_cased-ae5711deb3.spiece" # Kobert vocab
vocab_file="Tokenizer/kobert/kobert_news_wiki_ko_cased-ae5711deb3.spiece" # Kobert vocab
speical_token = ["[UNK]", "[PAD]", "[CLS]", "[SEP]", "[MASK]"]
SPVocabToWPVocab(vocab_file, outfile_fpath, first_special_token=speical_token)
# Out:
# sp:0, idx:[UNK]
# sp:1, idx:[PAD]
# sp:2, idx:[CLS]
# sp:3, idx:[SEP]
# sp:4, idx:[MASK]
# k:[UNK], idx:0
# k:[CLS], idx:2
# k:[SEP], idx:3
# k:[MASK], idx:4
# k:[PAD], idx:1
# k:!, idx:5
# k:!', idx:6
# k:!”, idx:7
# k:", idx:8
# k:#, idx:9
# k:$, idx:10
# k:%, idx:11
# k:%), idx:12
# k:&, idx:13
# k:&#34;, idx:14
# k:', idx:15
# k:'(, idx:16
# k:',, idx:17
# k:(, idx:18
# k:(0, idx:19
# k:(1, idx:20
# k:(10, idx:21
# k:(12, idx:22
# k:(15, idx:23
# k:(17, idx:24
# k:(18, idx:25
# k:(19, idx:26
# k:(2, idx:27
# k:(20, idx:28
# k:(23, idx:29
# k:(24, idx:30
# k:(25, idx:31
# k:(3, idx:32
# k:(4, idx:33
# k:(5, idx:34
# k:(6, idx:35
# k:(7, idx:36
# k:(8, idx:37
# k:(9, idx:38
# k:(?), idx:39
# k:), idx:40
# k:)', idx:41
# k:),, idx:42
# k:)’, idx:43
# k:*, idx:44
# k:+, idx:45
# k:,, idx:46
# k:-, idx:47
# k:----------------, idx:48
# k:-1, idx:49
# k:-2, idx:50
# k:-20, idx:51
# k:-3, idx:52
# k:-4, idx:53
# k:., idx:54
# k:..., idx:55
# k:...", idx:56
# k:...', idx:57
# ...

# %%
speical_folder = "my_data1/special_0214"
AddWPVocabSpecialToken(outfile_fpath, speical_folder)
# Out:
# speicaltoken: 'my_data1/special_0214' create!!
